# %% [markdown]
# ## Description:
# #### Predicting the age of abalone from physical measurements. The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# ## Attribute Information:
# ### Given is the attribute name, attribute type, measurement unit, and a brief description. The number of rings is the value to predict: either as a continuous value or as a classification problem.
#
# ## Name / Data Type / Measurement Unit / Description
# ### 1- Sex / nominal / -- / M, F, and I (infant)
# ### 2- Length / continuous / mm / Longest shell measurement
# ### 3- Diameter / continuous / mm / perpendicular to length
# ### 4- Height / continuous / mm / with meat in shell
# ### 5- Whole weight / continuous / grams / whole abalone
# ### 6- Shucked weight / continuous / grams / weight of meat
# ### 7- Viscera weight / continuous / grams / gut weight (after bleeding)
# ### 8- Shell weight / continuous / grams / after being dried
# ### 9- Rings / integer / -- / +1.5 gives the age in years Building a Regression Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import scale

# %%
df=pd.read_csv("../abalone.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# ## Visualizations.

# %% [markdown]
# ### Univariate Analysis

# %%
plt.hist(df["Whole weight"])
# Out:
# (array([632., 783., 827., 824., 616., 286., 129.,  58.,  16.,   6.]),
#  array([2.00000e-03, 2.84350e-01, 5.66700e-01, 8.49050e-01, 1.13140e+00,
#         1.41375e+00, 1.69610e+00, 1.97845e+00, 2.26080e+00, 2.54315e+00,
#         2.82550e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(df["Viscera weight"].value_counts(),labels=df["Viscera weight"].unique())
plt.show()

# %% [markdown]
# ### Bi-Variate Analysis

# %%
sns.lineplot(x=df.Length,y=df.Diameter)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Diameter'>

# %%
plt.bar(df.Sex,df.Length)
# Out:
# <BarContainer object of 4177 artists>

# %% [markdown]
# ### Multi-Variate Analysis

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Perform descriptive statistics on the dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# ## Check for Missing values and deal with them

# %%
df.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %% [markdown]
# ## Find the outliers and replace them outliers

# %%
sns.boxplot(x=df["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings'>

# %%
q1=df.Length.quantile(0.25)
q2=df.Length.quantile(0.75)
IQR = q2-q1
upper_limit = q2+1.5*IQR
lower_limit = q2-1.5*IQR
print(upper_limit)
print(lower_limit)
df["Length"].head()
# Out:
# 0.8624999999999999
# 0.36750000000000005
# 0    0.455
# 1    0.350
# 2    0.530
# 3    0.440
# 4    0.330
# Name: Length, dtype: float64

# %%
df.median()
# Out:
# C:\Users\navan\AppData\Local\Temp\ipykernel_11024\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Length            0.5750
# Diameter          0.4250
# Height            0.1400
# Whole weight      0.7995
# Shucked weight    0.3360
# Viscera weight    0.1710
# Shell weight      0.2340
# Rings             9.0000
# dtype: float64

# %%
df["Length"]=np.where(df["Length"]<lower_limit,6.52,df["Length"])

# %%
df["Length"]=np.where(df["Length"]<lower_limit,6.52,df["Length"])
sns.violinplot(x=df["Length"])
# Out:
# <AxesSubplot:xlabel='Length'>

# %% [markdown]
# ## Check for Categorical columns and perform encoding

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   6.520     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   6.520     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
le=LabelEncoder()
df.Sex=le.fit_transform(df.Sex)

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   6.520     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   6.520     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# ## Split the data into dependent and independent variables

# %%
y=df["Rings"]
x=df.drop("Rings",axis=1)

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   6.520     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   6.520     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %% [markdown]
# ## Scale the independent variables

# %%
scaled_x=pd.DataFrame(scale(x),columns=x.columns)
scaled_x
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.411890 -0.432149 -1.064424     -0.641898       -0.607685
# 1     1.151980  2.772531 -1.439929 -1.183978     -1.230277       -1.170910
# 2    -1.280690 -0.372511  0.122130 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.419766 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -0.064355  2.772531 -1.540707 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.280690 -0.354135  0.424464  0.609334      0.118813        0.047908
# 4173  1.151980 -0.341008  0.323686 -0.107991      0.279929        0.358808
# 4174  1.151980 -0.335758  0.676409  1.565767      0.708212        0.748559
# 4175 -1.280690 -0.322632  0.777187  0.250672      0.541998        0.773341
# 4176  1.151980 -0.278002  1.482634  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight
# 0          -0.726212     -0.638217
# 1          -1.205221     -1.212987
# 2          -0.356690     -0.207139
# 3          -0.607600     -0.602294
# 4          -1.287337     -1.320757
# ...              ...           ...
# 4172        0.532900      0.073062
# 4173        0.309362      0.155685
# 4174        0.975413      0.496955
# 4175        0.733627      0.410739
# 4176        1.787449      1.840481
#
# [4177 rows x 8 columns]

# %% [markdown]
# ## Split the data into training and testing

# %%
xtrain,xtest,ytrain,ytest=train_test_split(scaled_x,y,test_size=0.3,random_state=0)
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (2923, 8) (1254, 8) (2923,) (1254,)

# %%
xtrain
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 1376  1.151980 -0.325257  1.029133  0.848442      0.923373        0.955826
# 1225 -0.064355  2.772531 -1.540707 -1.303532     -1.281263       -1.146128
# 2722 -0.064355 -0.453894 -1.339151 -1.064424     -1.222119       -1.191186
# 3387  1.151980 -0.364636  0.021352  0.131117      0.090261       -0.251727
# 2773 -1.280690 -0.346259  0.575631  0.131117      0.321738        0.498488
# ...        ...       ...       ...       ...           ...             ...
# 1033  1.151980 -0.309505  1.180300  1.087551      1.617803        1.374865
# 3264 -1.280690 -0.306880  0.928354  0.011563      0.696995        0.816146
# 1653  1.151980 -0.338383  0.424464  0.131117      0.265653        0.466947
# 2607 -1.280690 -0.322632  0.827576  0.609334      0.608279        0.530028
# 2732 -0.064355 -0.435517 -0.835261 -0.705762     -1.025313       -1.022219
#
#       Viscera weight  Shell weight
# 1376        0.528338      1.086094
# 1225       -1.310147     -1.356680
# 2722       -1.150477     -1.241726
# 3387        0.140568      0.511324
# 2773        0.318486      0.080246
# ...              ...           ...
# 1033        1.294753      1.711157
# 3264        1.249133      0.331708
# 1653        0.236370      0.105392
# 2607        0.510090      0.572393
# 2732       -0.963435     -0.990264
#
# [2923 rows x 8 columns]

# %%
xtest
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 668   1.151980 -0.362010  0.172519  0.370226      0.181016       -0.368878
# 1580 -0.064355 -0.388263 -0.079426 -0.466653     -0.433875       -0.443224
# 3784  1.151980 -0.325257  0.726798  0.370226      0.870348        0.755318
# 463  -0.064355  2.772531 -2.447709 -2.020857     -1.579022       -1.522362
# 2615  1.151980 -0.312131  0.928354  0.848442      1.390405        1.415417
# ...        ...       ...       ...       ...           ...             ...
# 1052  1.151980 -0.249125  1.936135  1.924430      3.004623        2.918100
# 3439 -0.064355 -0.419766 -0.583316 -0.347099     -0.760186       -0.673019
# 1174 -1.280690 -0.317381  0.877965 -2.977291      0.668443        0.685478
# 2210  1.151980 -0.304255  0.978743  1.446213      1.635138        0.572833
# 2408 -0.064355 -0.325257  0.777187  0.728888      0.773474        0.545798
#
#       Viscera weight  Shell weight
# 668         0.569396      0.690940
# 1580       -0.343004     -0.325685
# 3784        1.764639      0.565209
# 463        -1.538247     -1.572219
# 2615        1.778325      0.996287
# ...              ...           ...
# 1052        2.996378      2.742152
# 3439       -0.776394     -0.774725
# 1174        1.162455      0.356854
# 2210        1.062091      2.666713
# 2408        1.130521      0.655017
#
# [1254 rows x 8 columns]

# %%
ytrain
# Out:
# 1376    10
# 1225     5
# 2722     7
# 3387    18
# 2773    11
#         ..
# 1033    10
# 3264    12
# 1653    10
# 2607     9
# 2732     8
# Name: Rings, Length: 2923, dtype: int64

# %%
ytest
# Out:
# 668     13
# 1580     8
# 3784    11
# 463      5
# 2615    12
#         ..
# 1052    12
# 3439     8
# 1174     9
# 2210    18
# 2408    15
# Name: Rings, Length: 1254, dtype: int64

# %% [markdown]
# ## Build the Model

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ## Train the Model

# %%
Y_pred_train = model.predict(xtrain)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(ytrain, Y_pred_train))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(ytrain, Y_pred_train))
# Out:
# Coefficients: [ 0.06815161 -0.23562734  0.86178154  0.3092917   4.63014369 -4.50274278
#  -1.04170943  1.38824653]
# Intercept: 9.915811102632894
# Mean squared error (MSE): 4.80
# Coefficient of determination (R^2): 0.54

# %% [markdown]
# ## Test the Model

# %%
Y_pred_test = model.predict(xtest)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(ytest, Y_pred_test))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(ytest, Y_pred_test))
# Out:
# Coefficients: [ 0.06815161 -0.23562734  0.86178154  0.3092917   4.63014369 -4.50274278
#  -1.04170943  1.38824653]
# Intercept: 9.915811102632894
# Mean squared error (MSE): 5.10
# Coefficient of determination (R^2): 0.52
